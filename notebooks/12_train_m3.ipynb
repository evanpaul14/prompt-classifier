# %% [markdown]
# # 12 — Model 3: Frozen RoBERTa + Classification Head
#
# RoBERTa CLS embeddings cached to Drive. Only head is trained.
#
# **Runtime:** GPU (T4 minimum for encoding; head training is fast on CPU too).

# %%
import os, sys
os.chdir('/content/polygence'); sys.path.insert(0, 'src')
from prompt_classifier.seeds import set_all_seeds; set_all_seeds(42)

# %%
import torch
print('CUDA:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

# %%
from prompt_classifier.models.m3_roberta_frozen import run
report = run('configs/model3_roberta_frozen.yaml')
print(report)

# %%
print('FPR target met:', report['targets_met']['fpr_ok'])
print('FNR target met:', report['targets_met']['fnr_ok'])
