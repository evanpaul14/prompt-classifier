# %% [markdown]
# # 20 — Aggregate Evaluation
#
# Collect all `reports/*.json` and generate `reports/comparison.md`.
#
# **Runtime:** CPU.

# %%
import os, sys
os.chdir('/content/polygence'); sys.path.insert(0, 'src')

# %%
import subprocess
result = subprocess.run([sys.executable, 'scripts/eval_all.py'], capture_output=True, text=True)
print(result.stdout)
if result.returncode != 0:
    print('STDERR:', result.stderr)

# %%
from IPython.display import Markdown
with open('reports/comparison.md') as f:
    display(Markdown(f.read()))
